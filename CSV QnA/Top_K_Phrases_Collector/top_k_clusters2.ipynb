# %% [markdown]
# Main Code

# %%
import base64
import pandas as pd
from io import StringIO
from sklearn.feature_extraction.text import TfidfVectorizer  # TF-IDF + n-grams
from typing import Dict, Any, List, Tuple
import numpy as np


def sfs_to_df(
    file_content
) -> pd.DataFrame:
    try:
        decoded_content = base64.b64decode(file_content).decode('utf-8')
    except Exception:
        decoded_content = file_content
    csv_buffer = StringIO(decoded_content)
    df = pd.read_csv(csv_buffer)
    return df


def do_tfidf(
    documents: List[str], 
    min_phrase_length: int = 3, 
    max_phrase_length: int = 3
) -> Tuple[np.ndarray, List[str]]:
    tfidf_vectorizer = TfidfVectorizer(
        lowercase=True,
        stop_words='english',
        ngram_range=(min_phrase_length, max_phrase_length),
        min_df=2,
        max_df=0.95
    )
    tfidf_matrix = tfidf_vectorizer.fit_transform(documents)
    feature_names = tfidf_vectorizer.get_feature_names_out()
    return tfidf_matrix, feature_names


def calc_percentages(
    total_respondents: int, 
    tfidf_matrix: np.ndarray, 
    feature_names: List[str]
) -> List[Tuple[str, float]]:
    phrase_freq_pairs = {}
    for i, phrase in enumerate(feature_names):
        # Binary count non-zero entries in the TF-IDF matrix for this phrase
        phrase_freq = (tfidf_matrix[:, i] > 0).sum()
        phrase_freq_pairs[phrase] = phrase_freq
    phrase_percentage_pairs = []
    for phrase, phrase_freq in phrase_freq_pairs.items():
        percentage = (phrase_freq / total_respondents) * 100
        phrase_percentage_pair = (phrase, percentage)
        phrase_percentage_pairs.append(phrase_percentage_pair)
    return phrase_percentage_pairs


def get_top_K(
    K: int, 
    results: List[Tuple[str, float]]
) -> List[Tuple[str, float]]:
    results.sort(key=lambda x: x[1], reverse=True)
    top_k_ngrams = results[:K]
    return top_k_ngrams


def handler(
    input_data: Dict[str, Any]
) -> Dict[str, Any]:
    file_content = input_data.get("File").get("content")
    K = input_data.get("K", 5)
    df = sfs_to_df(file_content)
    documents = df.iloc[:, 1]  # use col 2

    tfidf_matrix, feature_names = do_tfidf(documents, 1, 3)
    phrase_percentage_pairs = calc_percentages(len(documents), tfidf_matrix, feature_names)
    top_k_ngrams = get_top_K(K, phrase_percentage_pairs)
    return top_k_ngrams

# %% [markdown]
# Simulating node being run ...

# %%
import top_k_phrases_main as tkm
tkm.main("questionnaire responses.csv", 5)
# Out:
# Processing CSV file: questionnaire responses.csv
# The top 5 Phrases are:
# • ??? — 91.67% mention: clients
# • ??? — 91.67% mention: managers
# • ??? — 91.67% mention: need
# • ??? — 83.33% mention: marketing
# • ??? — 83.33% mention: sales

# %% [markdown]
# Testing

# %%
K = 5
csv_file_path = "questionnaire responses.csv"
df = pd.read_csv(csv_file_path, encoding='latin1')
documents = df.iloc[:, 1]

tfidf_matrix, feature_names = do_tfidf(documents, 1, 3)
print(tfidf_matrix)
feature_names
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 1019 stored elements and shape (12, 246)>
#   Coords	Values
#   (0, 24)	0.09530449320891317
#   (0, 94)	0.08098845740963533
#   (0, 46)	0.08098845740963533
#   (0, 33)	0.06929140446470394
#   (0, 128)	0.08098845740963533
#   (0, 173)	0.08098845740963533
#   (0, 230)	0.08774798465164782
#   (0, 140)	0.13858280892940789
#   (0, 61)	0.08774798465164782
#   (0, 0)	0.15823074232701018
#   (0, 189)	0.07487372123160878
#   (0, 123)	0.07487372123160878
#   (0, 116)	0.06929140446470394
#   (0, 59)	0.15823074232701018
#   (0, 64)	0.09530449320891317
#   (0, 200)	0.09530449320891317
#   (0, 105)	0.15823074232701018
#   (0, 197)	0.09530449320891317
#   (0, 179)	0.09530449320891317
#   (0, 30)	0.08774798465164782
#   (0, 233)	0.08098845740963533
#   (0, 19)	0.08774798465164782
#   (0, 87)	0.08774798465164782
#   (0, 113)	0.09530449320891317
#   (0, 211)	0.09530449320891317
#   :	:
#   (11, 144)	0.10897318633401004
#   (11, 181)	0.10897318633401004
#   (11, 32)	0.09205788627253741
#   (11, 235)	0.09205788627253741
#   (11, 22)	0.13162023005424142
#   (11, 91)	0.13162023005424142
#   (11, 115)	0.0999855464705899
#   (11, 213)	0.0999855464705899
#   (11, 205)	0.0999855464705899
#   (11, 164)	0.10897318633401004
#   (11, 136)	0.10897318633401004
#   (11, 5)	0.16600253259133435
#   (11, 132)	0.14663942395043705
#   (11, 238)	0.10897318633401004
#   (11, 121)	0.14663942395043705
#   (11, 122)	0.14663942395043705
#   (11, 145)	0.13162023005424142
#   (11, 239)	0.11934865511148722
#   (11, 207)	0.16600253259133435
#   (11, 17)	0.16600253259133435
#   (11, 208)	0.16600253259133435
#   (11, 148)	0.3320050651826687
#   (11, 1)	0.3320050651826687
#   (11, 2)	0.14663942395043705
#   (11, 86)	0.16600253259133435
# array(['android', 'attractive', 'audience', 'audience sales',
#        'audience sales marketing', 'audiences', 'awareness', 'best',
#        'brands', 'buttons', 'calculator', 'calculator sales',
#        'calculator sales pitch', 'calculator training',
#        'calculator training design', 'case', 'case studies',
#        'case studies pricing', 'case studies sales', 'cases',
#        'cases industry', 'cases industry hands', 'cases industry local',
#        'challenge', 'challenging', 'challenging introduce',
#        'challenging introduce rcs', 'challenging iâ', 'challenging iâ ve',
#        'channels', 'clear', 'clear use', 'clear use cases', 'clients',
#        'clients familiar', 'clients familiar rcs', 'clients know',
#        'clients meet', 'clients meet relevant', 'clients moved',
#        'clients moved forwardâ', 'compare', 'compared', 'conversation',
#        'conversation flows', 'conversation flows clients',
#        'conversations', 'conversations clients',
#        'conversations clients meet', 'ctr', 'curious', 'curious hesitant',
#        'demos', 'demos live', 'demos live simulations', 'design',
#        'design conversation', 'design conversation flows', 'directly',
#        'directors', 'easy', 'education', 'education rich',
#        'education rich media', 'executive', 'executive specialist',
#        'executive specialist managers', 'experience', 'familiar',
#        'familiar rcs', 'features', 'flows', 'flows clients', 'forwardâ',
#        'forwardâ unfamiliar', 'forwardâ unfamiliar need', 'hands',
#        'hands demos', 'hands demos live', 'help', 'hesitant', 'image',
#        'images', 'images videos', 'improve', 'inbox', 'increase',
#        'industry', 'industry hands', 'industry hands demos',
#        'industry local', 'industry local success', 'interactive',
#        'interactive features', 'introduce', 'introduce rcs',
#        'introduce rcs conversations', 'ios', 'iâ', 'iâ like',
#        'iâ like support', 'iâ ve', 'iâ ve pitched', 'know', 'lead',
#        'level', 'like', 'like support', 'like support local', 'limited',
#        'limited reach', 'live', 'live simulations', 'local',
#        'local success', 'local success stories', 'managers',
#        'managers executive', 'managers executive specialist',
#        'managers iâ', 'managers iâ like', 'managers somewhat',
#        'managers somewhat need', 'marketing', 'marketing executive',
#        'marketing executive specialist', 'marketing managers', 'media',
#        'meet', 'meet relevant', 'meet relevant curious',
#        'meet relevant unfamiliar', 'message', 'messaging', 'models',
#        'models roi', 'models roi calculator', 'moved', 'moved forwardâ',
#        'moved forwardâ unfamiliar', 'need', 'need education',
#        'need education rich', 'need resources', 'need resources clear',
#        'neutral', 'neutral introduce', 'neutral introduce rcs', 'number',
#        'occasionally', 'occasionally clients',
#        'occasionally clients moved', 'offers', 'open', 'people', 'pitch',
#        'pitch templates', 'pitch templates pricing',
#        'pitch templates training', 'pitched', 'pitched occasionally',
#        'pitched occasionally clients', 'pricing', 'pricing models',
#        'pricing models roi', 'product', 'products', 'quick',
#        'rcs conversations', 'rcs conversations clients', 'rcs rich',
#        'reach', 'read', 'relevant', 'relevant curious',
#        'relevant curious hesitant', 'relevant unfamiliar',
#        'relevant unfamiliar need', 'reply', 'resources',
#        'resources clear', 'resources clear use', 'rich', 'rich media',
#        'richer', 'roi', 'roi calculator', 'roi calculator sales',
#        'roi calculator training', 'sales', 'sales marketing',
#        'sales marketing executive', 'sales pitch',
#        'sales pitch templates', 'sessions', 'simulations', 'sms',
#        'somewhat', 'somewhat need', 'somewhat need resources',
#        'specialist', 'specialist managers', 'specialist managers iâ',
#        'stories', 'stories case', 'stories case studies', 'studies',
#        'studies pricing', 'studies pricing models', 'studies sales',
#        'studies sales pitch', 'success', 'success stories',
#        'success stories case', 'support', 'support local',
#        'support local success', 'targeting', 'team', 'telkomsel',
#        'templates', 'templates pricing', 'templates pricing models',
#        'templates training', 'templates training design', 'text',
#        'training', 'training design', 'training design conversation',
#        'understand', 'unfamiliar', 'unfamiliar need',
#        'unfamiliar need education', 'use', 'use cases',
#        'use cases industry', 'use rcs', 'used', 'user', 'users', 'value',
#        've', 've pitched', 've pitched occasionally', 'videos',
#        'whatsapp'], dtype=object)

# %%
phrase_percentage_pairs = calc_percentages(len(documents), tfidf_matrix, feature_names)
phrase_percentage_pairs
# Out:
# [('android', np.float64(16.666666666666664)),
#  ('attractive', np.float64(16.666666666666664)),
#  ('audience', np.float64(25.0)),
#  ('audience sales', np.float64(16.666666666666664)),
#  ('audience sales marketing', np.float64(16.666666666666664)),
#  ('audiences', np.float64(16.666666666666664)),
#  ('awareness', np.float64(16.666666666666664)),
#  ('best', np.float64(16.666666666666664)),
#  ('brands', np.float64(16.666666666666664)),
#  ('buttons', np.float64(16.666666666666664)),
#  ('calculator', np.float64(50.0)),
#  ('calculator sales', np.float64(16.666666666666664)),
#  ('calculator sales pitch', np.float64(16.666666666666664)),
#  ('calculator training', np.float64(16.666666666666664)),
#  ('calculator training design', np.float64(16.666666666666664)),
#  ('case', np.float64(66.66666666666666)),
#  ('case studies', np.float64(58.333333333333336)),
#  ('case studies pricing', np.float64(16.666666666666664)),
#  ('case studies sales', np.float64(16.666666666666664)),
#  ('cases', np.float64(66.66666666666666)),
#  ('cases industry', np.float64(66.66666666666666)),
#  ('cases industry hands', np.float64(16.666666666666664)),
#  ('cases industry local', np.float64(33.33333333333333)),
#  ('challenge', np.float64(16.666666666666664)),
#  ('challenging', np.float64(58.333333333333336)),
#  ('challenging introduce', np.float64(41.66666666666667)),
#  ('challenging introduce rcs', np.float64(41.66666666666667)),
#  ('challenging iâ', np.float64(16.666666666666664)),
#  ('challenging iâ ve', np.float64(16.666666666666664)),
#  ('channels', np.float64(16.666666666666664)),
#  ('clear', np.float64(66.66666666666666)),
#  ('clear use', np.float64(66.66666666666666)),
#  ('clear use cases', np.float64(66.66666666666666)),
#  ('clients', np.float64(91.66666666666666)),
#  ('clients familiar', np.float64(16.666666666666664)),
#  ('clients familiar rcs', np.float64(16.666666666666664)),
#  ('clients know', np.float64(16.666666666666664)),
#  ('clients meet', np.float64(75.0)),
#  ('clients meet relevant', np.float64(75.0)),
#  ('clients moved', np.float64(16.666666666666664)),
#  ('clients moved forwardâ', np.float64(16.666666666666664)),
#  ('compare', np.float64(16.666666666666664)),
#  ('compared', np.float64(25.0)),
#  ('conversation', np.float64(33.33333333333333)),
#  ('conversation flows', np.float64(33.33333333333333)),
#  ('conversation flows clients', np.float64(16.666666666666664)),
#  ('conversations', np.float64(75.0)),
#  ('conversations clients', np.float64(75.0)),
#  ('conversations clients meet', np.float64(75.0)),
#  ('ctr', np.float64(16.666666666666664)),
#  ('curious', np.float64(33.33333333333333)),
#  ('curious hesitant', np.float64(33.33333333333333)),
#  ('demos', np.float64(33.33333333333333)),
#  ('demos live', np.float64(33.33333333333333)),
#  ('demos live simulations', np.float64(33.33333333333333)),
#  ('design', np.float64(33.33333333333333)),
#  ('design conversation', np.float64(33.33333333333333)),
#  ('design conversation flows', np.float64(33.33333333333333)),
#  ('directly', np.float64(25.0)),
#  ('directors', np.float64(16.666666666666664)),
#  ('easy', np.float64(16.666666666666664)),
#  ('education', np.float64(66.66666666666666)),
#  ('education rich', np.float64(25.0)),
#  ('education rich media', np.float64(16.666666666666664)),
#  ('executive', np.float64(58.333333333333336)),
#  ('executive specialist', np.float64(58.333333333333336)),
#  ('executive specialist managers', np.float64(25.0)),
#  ('experience', np.float64(16.666666666666664)),
#  ('familiar', np.float64(33.33333333333333)),
#  ('familiar rcs', np.float64(16.666666666666664)),
#  ('features', np.float64(16.666666666666664)),
#  ('flows', np.float64(33.33333333333333)),
#  ('flows clients', np.float64(16.666666666666664)),
#  ('forwardâ', np.float64(16.666666666666664)),
#  ('forwardâ unfamiliar', np.float64(16.666666666666664)),
#  ('forwardâ unfamiliar need', np.float64(16.666666666666664)),
#  ('hands', np.float64(33.33333333333333)),
#  ('hands demos', np.float64(33.33333333333333)),
#  ('hands demos live', np.float64(33.33333333333333)),
#  ('help', np.float64(16.666666666666664)),
#  ('hesitant', np.float64(33.33333333333333)),
#  ('image', np.float64(16.666666666666664)),
#  ('images', np.float64(16.666666666666664)),
#  ('images videos', np.float64(16.666666666666664)),
#  ('improve', np.float64(16.666666666666664)),
#  ('inbox', np.float64(16.666666666666664)),
#  ('increase', np.float64(16.666666666666664)),
#  ('industry', np.float64(66.66666666666666)),
#  ('industry hands', np.float64(16.666666666666664)),
#  ('industry hands demos', np.float64(16.666666666666664)),
#  ('industry local', np.float64(33.33333333333333)),
#  ('industry local success', np.float64(33.33333333333333)),
#  ('interactive', np.float64(50.0)),
#  ('interactive features', np.float64(16.666666666666664)),
#  ('introduce', np.float64(75.0)),
#  ('introduce rcs', np.float64(75.0)),
#  ('introduce rcs conversations', np.float64(75.0)),
#  ('ios', np.float64(16.666666666666664)),
#  ('iâ', np.float64(41.66666666666667)),
#  ('iâ like', np.float64(33.33333333333333)),
#  ('iâ like support', np.float64(33.33333333333333)),
#  ('iâ ve', np.float64(16.666666666666664)),
#  ('iâ ve pitched', np.float64(16.666666666666664)),
#  ('know', np.float64(25.0)),
#  ('lead', np.float64(16.666666666666664)),
#  ('level', np.float64(16.666666666666664)),
#  ('like', np.float64(41.66666666666667)),
#  ('like support', np.float64(33.33333333333333)),
#  ('like support local', np.float64(16.666666666666664)),
#  ('limited', np.float64(25.0)),
#  ('limited reach', np.float64(16.666666666666664)),
#  ('live', np.float64(33.33333333333333)),
#  ('live simulations', np.float64(33.33333333333333)),
#  ('local', np.float64(58.333333333333336)),
#  ('local success', np.float64(58.333333333333336)),
#  ('local success stories', np.float64(58.333333333333336)),
#  ('managers', np.float64(91.66666666666666)),
#  ('managers executive', np.float64(16.666666666666664)),
#  ('managers executive specialist', np.float64(16.666666666666664)),
#  ('managers iâ', np.float64(16.666666666666664)),
#  ('managers iâ like', np.float64(16.666666666666664)),
#  ('managers somewhat', np.float64(25.0)),
#  ('managers somewhat need', np.float64(25.0)),
#  ('marketing', np.float64(83.33333333333334)),
#  ('marketing executive', np.float64(25.0)),
#  ('marketing executive specialist', np.float64(25.0)),
#  ('marketing managers', np.float64(25.0)),
#  ('media', np.float64(25.0)),
#  ('meet', np.float64(75.0)),
#  ('meet relevant', np.float64(75.0)),
#  ('meet relevant curious', np.float64(33.33333333333333)),
#  ('meet relevant unfamiliar', np.float64(41.66666666666667)),
#  ('message', np.float64(25.0)),
#  ('messaging', np.float64(25.0)),
#  ('models', np.float64(50.0)),
#  ('models roi', np.float64(50.0)),
#  ('models roi calculator', np.float64(50.0)),
#  ('moved', np.float64(16.666666666666664)),
#  ('moved forwardâ', np.float64(16.666666666666664)),
#  ('moved forwardâ unfamiliar', np.float64(16.666666666666664)),
#  ('need', np.float64(91.66666666666666)),
#  ('need education', np.float64(58.333333333333336)),
#  ('need education rich', np.float64(25.0)),
#  ('need resources', np.float64(58.333333333333336)),
#  ('need resources clear', np.float64(50.0)),
#  ('neutral', np.float64(33.33333333333333)),
#  ('neutral introduce', np.float64(25.0)),
#  ('neutral introduce rcs', np.float64(25.0)),
#  ('number', np.float64(16.666666666666664)),
#  ('occasionally', np.float64(16.666666666666664)),
#  ('occasionally clients', np.float64(16.666666666666664)),
#  ('occasionally clients moved', np.float64(16.666666666666664)),
#  ('offers', np.float64(16.666666666666664)),
#  ('open', np.float64(16.666666666666664)),
#  ('people', np.float64(33.33333333333333)),
#  ('pitch', np.float64(41.66666666666667)),
#  ('pitch templates', np.float64(41.66666666666667)),
#  ('pitch templates pricing', np.float64(16.666666666666664)),
#  ('pitch templates training', np.float64(16.666666666666664)),
#  ('pitched', np.float64(16.666666666666664)),
#  ('pitched occasionally', np.float64(16.666666666666664)),
#  ('pitched occasionally clients', np.float64(16.666666666666664)),
#  ('pricing', np.float64(50.0)),
#  ('pricing models', np.float64(50.0)),
#  ('pricing models roi', np.float64(50.0)),
#  ('product', np.float64(25.0)),
#  ('products', np.float64(16.666666666666664)),
#  ('quick', np.float64(16.666666666666664)),
#  ('rcs conversations', np.float64(75.0)),
#  ('rcs conversations clients', np.float64(75.0)),
#  ('rcs rich', np.float64(25.0)),
#  ('reach', np.float64(25.0)),
#  ('read', np.float64(16.666666666666664)),
#  ('relevant', np.float64(75.0)),
#  ('relevant curious', np.float64(33.33333333333333)),
#  ('relevant curious hesitant', np.float64(33.33333333333333)),
#  ('relevant unfamiliar', np.float64(41.66666666666667)),
#  ('relevant unfamiliar need', np.float64(41.66666666666667)),
#  ('reply', np.float64(16.666666666666664)),
#  ('resources', np.float64(58.333333333333336)),
#  ('resources clear', np.float64(50.0)),
#  ('resources clear use', np.float64(50.0)),
#  ('rich', np.float64(33.33333333333333)),
#  ('rich media', np.float64(25.0)),
#  ('richer', np.float64(16.666666666666664)),
#  ('roi', np.float64(58.333333333333336)),
#  ('roi calculator', np.float64(50.0)),
#  ('roi calculator sales', np.float64(16.666666666666664)),
#  ('roi calculator training', np.float64(16.666666666666664)),
#  ('sales', np.float64(83.33333333333334)),
#  ('sales marketing', np.float64(33.33333333333333)),
#  ('sales marketing executive', np.float64(16.666666666666664)),
#  ('sales pitch', np.float64(41.66666666666667)),
#  ('sales pitch templates', np.float64(41.66666666666667)),
#  ('sessions', np.float64(16.666666666666664)),
#  ('simulations', np.float64(33.33333333333333)),
#  ('sms', np.float64(66.66666666666666)),
#  ('somewhat', np.float64(58.333333333333336)),
#  ('somewhat need', np.float64(58.333333333333336)),
#  ('somewhat need resources', np.float64(58.333333333333336)),
#  ('specialist', np.float64(58.333333333333336)),
#  ('specialist managers', np.float64(25.0)),
#  ('specialist managers iâ', np.float64(16.666666666666664)),
#  ('stories', np.float64(58.333333333333336)),
#  ('stories case', np.float64(58.333333333333336)),
#  ('stories case studies', np.float64(58.333333333333336)),
#  ('studies', np.float64(58.333333333333336)),
#  ('studies pricing', np.float64(16.666666666666664)),
#  ('studies pricing models', np.float64(16.666666666666664)),
#  ('studies sales', np.float64(16.666666666666664)),
#  ('studies sales pitch', np.float64(16.666666666666664)),
#  ('success', np.float64(58.333333333333336)),
#  ('success stories', np.float64(58.333333333333336)),
#  ('success stories case', np.float64(58.333333333333336)),
#  ('support', np.float64(50.0)),
#  ('support local', np.float64(16.666666666666664)),
#  ('support local success', np.float64(16.666666666666664)),
#  ('targeting', np.float64(16.666666666666664)),
#  ('team', np.float64(16.666666666666664)),
#  ('telkomsel', np.float64(25.0)),
#  ('templates', np.float64(50.0)),
#  ('templates pricing', np.float64(16.666666666666664)),
#  ('templates pricing models', np.float64(16.666666666666664)),
#  ('templates training', np.float64(16.666666666666664)),
#  ('templates training design', np.float64(16.666666666666664)),
#  ('text', np.float64(25.0)),
#  ('training', np.float64(41.66666666666667)),
#  ('training design', np.float64(33.33333333333333)),
#  ('training design conversation', np.float64(33.33333333333333)),
#  ('understand', np.float64(16.666666666666664)),
#  ('unfamiliar', np.float64(66.66666666666666)),
#  ('unfamiliar need', np.float64(58.333333333333336)),
#  ('unfamiliar need education', np.float64(58.333333333333336)),
#  ('use', np.float64(75.0)),
#  ('use cases', np.float64(66.66666666666666)),
#  ('use cases industry', np.float64(66.66666666666666)),
#  ('use rcs', np.float64(16.666666666666664)),
#  ('used', np.float64(25.0)),
#  ('user', np.float64(50.0)),
#  ('users', np.float64(41.66666666666667)),
#  ('value', np.float64(16.666666666666664)),
#  ('ve', np.float64(16.666666666666664)),
#  ('ve pitched', np.float64(16.666666666666664)),
#  ('ve pitched occasionally', np.float64(16.666666666666664)),
#  ('videos', np.float64(16.666666666666664)),
#  ('whatsapp', np.float64(25.0))]

# %%
phrase_percentage_pairs.sort(key=lambda x: x[1], reverse=True)
phrase_percentage_pairs
# Out:
# [('clients', np.float64(91.66666666666666)),
#  ('managers', np.float64(91.66666666666666)),
#  ('need', np.float64(91.66666666666666)),
#  ('marketing', np.float64(83.33333333333334)),
#  ('sales', np.float64(83.33333333333334)),
#  ('clients meet', np.float64(75.0)),
#  ('clients meet relevant', np.float64(75.0)),
#  ('conversations', np.float64(75.0)),
#  ('conversations clients', np.float64(75.0)),
#  ('conversations clients meet', np.float64(75.0)),
#  ('introduce', np.float64(75.0)),
#  ('introduce rcs', np.float64(75.0)),
#  ('introduce rcs conversations', np.float64(75.0)),
#  ('meet', np.float64(75.0)),
#  ('meet relevant', np.float64(75.0)),
#  ('rcs conversations', np.float64(75.0)),
#  ('rcs conversations clients', np.float64(75.0)),
#  ('relevant', np.float64(75.0)),
#  ('use', np.float64(75.0)),
#  ('case', np.float64(66.66666666666666)),
#  ('cases', np.float64(66.66666666666666)),
#  ('cases industry', np.float64(66.66666666666666)),
#  ('clear', np.float64(66.66666666666666)),
#  ('clear use', np.float64(66.66666666666666)),
#  ('clear use cases', np.float64(66.66666666666666)),
#  ('education', np.float64(66.66666666666666)),
#  ('industry', np.float64(66.66666666666666)),
#  ('sms', np.float64(66.66666666666666)),
#  ('unfamiliar', np.float64(66.66666666666666)),
#  ('use cases', np.float64(66.66666666666666)),
#  ('use cases industry', np.float64(66.66666666666666)),
#  ('case studies', np.float64(58.333333333333336)),
#  ('challenging', np.float64(58.333333333333336)),
#  ('executive', np.float64(58.333333333333336)),
#  ('executive specialist', np.float64(58.333333333333336)),
#  ('local', np.float64(58.333333333333336)),
#  ('local success', np.float64(58.333333333333336)),
#  ('local success stories', np.float64(58.333333333333336)),
#  ('need education', np.float64(58.333333333333336)),
#  ('need resources', np.float64(58.333333333333336)),
#  ('resources', np.float64(58.333333333333336)),
#  ('roi', np.float64(58.333333333333336)),
#  ('somewhat', np.float64(58.333333333333336)),
#  ('somewhat need', np.float64(58.333333333333336)),
#  ('somewhat need resources', np.float64(58.333333333333336)),
#  ('specialist', np.float64(58.333333333333336)),
#  ('stories', np.float64(58.333333333333336)),
#  ('stories case', np.float64(58.333333333333336)),
#  ('stories case studies', np.float64(58.333333333333336)),
#  ('studies', np.float64(58.333333333333336)),
#  ('success', np.float64(58.333333333333336)),
#  ('success stories', np.float64(58.333333333333336)),
#  ('success stories case', np.float64(58.333333333333336)),
#  ('unfamiliar need', np.float64(58.333333333333336)),
#  ('unfamiliar need education', np.float64(58.333333333333336)),
#  ('calculator', np.float64(50.0)),
#  ('interactive', np.float64(50.0)),
#  ('models', np.float64(50.0)),
#  ('models roi', np.float64(50.0)),
#  ('models roi calculator', np.float64(50.0)),
#  ('need resources clear', np.float64(50.0)),
#  ('pricing', np.float64(50.0)),
#  ('pricing models', np.float64(50.0)),
#  ('pricing models roi', np.float64(50.0)),
#  ('resources clear', np.float64(50.0)),
#  ('resources clear use', np.float64(50.0)),
#  ('roi calculator', np.float64(50.0)),
#  ('support', np.float64(50.0)),
#  ('templates', np.float64(50.0)),
#  ('user', np.float64(50.0)),
#  ('challenging introduce', np.float64(41.66666666666667)),
#  ('challenging introduce rcs', np.float64(41.66666666666667)),
#  ('iâ', np.float64(41.66666666666667)),
#  ('like', np.float64(41.66666666666667)),
#  ('meet relevant unfamiliar', np.float64(41.66666666666667)),
#  ('pitch', np.float64(41.66666666666667)),
#  ('pitch templates', np.float64(41.66666666666667)),
#  ('relevant unfamiliar', np.float64(41.66666666666667)),
#  ('relevant unfamiliar need', np.float64(41.66666666666667)),
#  ('sales pitch', np.float64(41.66666666666667)),
#  ('sales pitch templates', np.float64(41.66666666666667)),
#  ('training', np.float64(41.66666666666667)),
#  ('users', np.float64(41.66666666666667)),
#  ('cases industry local', np.float64(33.33333333333333)),
#  ('conversation', np.float64(33.33333333333333)),
#  ('conversation flows', np.float64(33.33333333333333)),
#  ('curious', np.float64(33.33333333333333)),
#  ('curious hesitant', np.float64(33.33333333333333)),
#  ('demos', np.float64(33.33333333333333)),
#  ('demos live', np.float64(33.33333333333333)),
#  ('demos live simulations', np.float64(33.33333333333333)),
#  ('design', np.float64(33.33333333333333)),
#  ('design conversation', np.float64(33.33333333333333)),
#  ('design conversation flows', np.float64(33.33333333333333)),
#  ('familiar', np.float64(33.33333333333333)),
#  ('flows', np.float64(33.33333333333333)),
#  ('hands', np.float64(33.33333333333333)),
#  ('hands demos', np.float64(33.33333333333333)),
#  ('hands demos live', np.float64(33.33333333333333)),
#  ('hesitant', np.float64(33.33333333333333)),
#  ('industry local', np.float64(33.33333333333333)),
#  ('industry local success', np.float64(33.33333333333333)),
#  ('iâ like', np.float64(33.33333333333333)),
#  ('iâ like support', np.float64(33.33333333333333)),
#  ('like support', np.float64(33.33333333333333)),
#  ('live', np.float64(33.33333333333333)),
#  ('live simulations', np.float64(33.33333333333333)),
#  ('meet relevant curious', np.float64(33.33333333333333)),
#  ('neutral', np.float64(33.33333333333333)),
#  ('people', np.float64(33.33333333333333)),
#  ('relevant curious', np.float64(33.33333333333333)),
#  ('relevant curious hesitant', np.float64(33.33333333333333)),
#  ('rich', np.float64(33.33333333333333)),
#  ('sales marketing', np.float64(33.33333333333333)),
#  ('simulations', np.float64(33.33333333333333)),
#  ('training design', np.float64(33.33333333333333)),
#  ('training design conversation', np.float64(33.33333333333333)),
#  ('audience', np.float64(25.0)),
#  ('compared', np.float64(25.0)),
#  ('directly', np.float64(25.0)),
#  ('education rich', np.float64(25.0)),
#  ('executive specialist managers', np.float64(25.0)),
#  ('know', np.float64(25.0)),
#  ('limited', np.float64(25.0)),
#  ('managers somewhat', np.float64(25.0)),
#  ('managers somewhat need', np.float64(25.0)),
#  ('marketing executive', np.float64(25.0)),
#  ('marketing executive specialist', np.float64(25.0)),
#  ('marketing managers', np.float64(25.0)),
#  ('media', np.float64(25.0)),
#  ('message', np.float64(25.0)),
#  ('messaging', np.float64(25.0)),
#  ('need education rich', np.float64(25.0)),
#  ('neutral introduce', np.float64(25.0)),
#  ('neutral introduce rcs', np.float64(25.0)),
#  ('product', np.float64(25.0)),
#  ('rcs rich', np.float64(25.0)),
#  ('reach', np.float64(25.0)),
#  ('rich media', np.float64(25.0)),
#  ('specialist managers', np.float64(25.0)),
#  ('telkomsel', np.float64(25.0)),
#  ('text', np.float64(25.0)),
#  ('used', np.float64(25.0)),
#  ('whatsapp', np.float64(25.0)),
#  ('android', np.float64(16.666666666666664)),
#  ('attractive', np.float64(16.666666666666664)),
#  ('audience sales', np.float64(16.666666666666664)),
#  ('audience sales marketing', np.float64(16.666666666666664)),
#  ('audiences', np.float64(16.666666666666664)),
#  ('awareness', np.float64(16.666666666666664)),
#  ('best', np.float64(16.666666666666664)),
#  ('brands', np.float64(16.666666666666664)),
#  ('buttons', np.float64(16.666666666666664)),
#  ('calculator sales', np.float64(16.666666666666664)),
#  ('calculator sales pitch', np.float64(16.666666666666664)),
#  ('calculator training', np.float64(16.666666666666664)),
#  ('calculator training design', np.float64(16.666666666666664)),
#  ('case studies pricing', np.float64(16.666666666666664)),
#  ('case studies sales', np.float64(16.666666666666664)),
#  ('cases industry hands', np.float64(16.666666666666664)),
#  ('challenge', np.float64(16.666666666666664)),
#  ('challenging iâ', np.float64(16.666666666666664)),
#  ('challenging iâ ve', np.float64(16.666666666666664)),
#  ('channels', np.float64(16.666666666666664)),
#  ('clients familiar', np.float64(16.666666666666664)),
#  ('clients familiar rcs', np.float64(16.666666666666664)),
#  ('clients know', np.float64(16.666666666666664)),
#  ('clients moved', np.float64(16.666666666666664)),
#  ('clients moved forwardâ', np.float64(16.666666666666664)),
#  ('compare', np.float64(16.666666666666664)),
#  ('conversation flows clients', np.float64(16.666666666666664)),
#  ('ctr', np.float64(16.666666666666664)),
#  ('directors', np.float64(16.666666666666664)),
#  ('easy', np.float64(16.666666666666664)),
#  ('education rich media', np.float64(16.666666666666664)),
#  ('experience', np.float64(16.666666666666664)),
#  ('familiar rcs', np.float64(16.666666666666664)),
#  ('features', np.float64(16.666666666666664)),
#  ('flows clients', np.float64(16.666666666666664)),
#  ('forwardâ', np.float64(16.666666666666664)),
#  ('forwardâ unfamiliar', np.float64(16.666666666666664)),
#  ('forwardâ unfamiliar need', np.float64(16.666666666666664)),
#  ('help', np.float64(16.666666666666664)),
#  ('image', np.float64(16.666666666666664)),
#  ('images', np.float64(16.666666666666664)),
#  ('images videos', np.float64(16.666666666666664)),
#  ('improve', np.float64(16.666666666666664)),
#  ('inbox', np.float64(16.666666666666664)),
#  ('increase', np.float64(16.666666666666664)),
#  ('industry hands', np.float64(16.666666666666664)),
#  ('industry hands demos', np.float64(16.666666666666664)),
#  ('interactive features', np.float64(16.666666666666664)),
#  ('ios', np.float64(16.666666666666664)),
#  ('iâ ve', np.float64(16.666666666666664)),
#  ('iâ ve pitched', np.float64(16.666666666666664)),
#  ('lead', np.float64(16.666666666666664)),
#  ('level', np.float64(16.666666666666664)),
#  ('like support local', np.float64(16.666666666666664)),
#  ('limited reach', np.float64(16.666666666666664)),
#  ('managers executive', np.float64(16.666666666666664)),
#  ('managers executive specialist', np.float64(16.666666666666664)),
#  ('managers iâ', np.float64(16.666666666666664)),
#  ('managers iâ like', np.float64(16.666666666666664)),
#  ('moved', np.float64(16.666666666666664)),
#  ('moved forwardâ', np.float64(16.666666666666664)),
#  ('moved forwardâ unfamiliar', np.float64(16.666666666666664)),
#  ('number', np.float64(16.666666666666664)),
#  ('occasionally', np.float64(16.666666666666664)),
#  ('occasionally clients', np.float64(16.666666666666664)),
#  ('occasionally clients moved', np.float64(16.666666666666664)),
#  ('offers', np.float64(16.666666666666664)),
#  ('open', np.float64(16.666666666666664)),
#  ('pitch templates pricing', np.float64(16.666666666666664)),
#  ('pitch templates training', np.float64(16.666666666666664)),
#  ('pitched', np.float64(16.666666666666664)),
#  ('pitched occasionally', np.float64(16.666666666666664)),
#  ('pitched occasionally clients', np.float64(16.666666666666664)),
#  ('products', np.float64(16.666666666666664)),
#  ('quick', np.float64(16.666666666666664)),
#  ('read', np.float64(16.666666666666664)),
#  ('reply', np.float64(16.666666666666664)),
#  ('richer', np.float64(16.666666666666664)),
#  ('roi calculator sales', np.float64(16.666666666666664)),
#  ('roi calculator training', np.float64(16.666666666666664)),
#  ('sales marketing executive', np.float64(16.666666666666664)),
#  ('sessions', np.float64(16.666666666666664)),
#  ('specialist managers iâ', np.float64(16.666666666666664)),
#  ('studies pricing', np.float64(16.666666666666664)),
#  ('studies pricing models', np.float64(16.666666666666664)),
#  ('studies sales', np.float64(16.666666666666664)),
#  ('studies sales pitch', np.float64(16.666666666666664)),
#  ('support local', np.float64(16.666666666666664)),
#  ('support local success', np.float64(16.666666666666664)),
#  ('targeting', np.float64(16.666666666666664)),
#  ('team', np.float64(16.666666666666664)),
#  ('templates pricing', np.float64(16.666666666666664)),
#  ('templates pricing models', np.float64(16.666666666666664)),
#  ('templates training', np.float64(16.666666666666664)),
#  ('templates training design', np.float64(16.666666666666664)),
#  ('understand', np.float64(16.666666666666664)),
#  ('use rcs', np.float64(16.666666666666664)),
#  ('value', np.float64(16.666666666666664)),
#  ('ve', np.float64(16.666666666666664)),
#  ('ve pitched', np.float64(16.666666666666664)),
#  ('ve pitched occasionally', np.float64(16.666666666666664)),
#  ('videos', np.float64(16.666666666666664))]

# %%
top_k_ngrams = phrase_percentage_pairs[:K]
top_k_ngrams
# Out:
# [('clients', np.float64(91.66666666666666)),
#  ('managers', np.float64(91.66666666666666)),
#  ('need', np.float64(91.66666666666666)),
#  ('marketing', np.float64(83.33333333333334)),
#  ('sales', np.float64(83.33333333333334))]
